# %%
import pandas as pd
import json

with open('features.json') as data_file:
    data = json.load(data_file)

df = pd.DataFrame(data["feature_stats"])

df = df.T

print(df.T.head())

hist = df.hist(column='spearman_corr_w_target_nomi_20_mean',bins=20)
# Out:
#                                           feature_honoured_observational_balaamite  \
# legacy_uniqueness                                                              NaN
# spearman_corr_w_target_nomi_20_mean                                      -0.000868
# spearman_corr_w_target_nomi_20_sharpe                                    -0.084973
# spearman_corr_w_target_nomi_20_reversals                                  0.000070
# spearman_corr_w_target_nomi_20_autocorr                                   0.032673
#
#                                           feature_polaroid_vadose_quinze  \
# legacy_uniqueness                                                    NaN
# spearman_corr_w_target_nomi_20_mean                             0.000162
# spearman_corr_w_target_nomi_20_sharpe                           0.016116
# spearman_corr_w_target_nomi_20_reversals                        0.000081
# spearman_corr_w_target_nomi_20_autocorr                        -0.012823
#
#                                           feature_untidy_withdrawn_bargeman  \
# legacy_uniqueness                                                       NaN
# spearman_corr_w_target_nomi_20_mean                               -0.000771
# spearman_corr_w_target_nomi_20_sharpe                             -0.087548
# spearman_corr_w_target_nomi_20_reversals                           0.000062
# spearman_corr_w_target_nomi_20_autocorr                            0.060474
#
#                                           feature_genuine_kyphotic_trehala  \
# legacy_uniqueness                                                      NaN
# spearman_corr_w_target_nomi_20_mean                               0.001220
# spearman_corr_w_target_nomi_20_sharpe                             0.093927
# spearman_corr_w_target_nomi_20_reversals                          0.000090
# spearman_corr_w_target_nomi_20_autocorr                           0.108851
#
#                                           feature_unenthralled_sportful_schoolhouse  \
# legacy_uniqueness                                                               NaN
# spearman_corr_w_target_nomi_20_mean                                        0.000975
# spearman_corr_w_target_nomi_20_sharpe                                      0.100378
# spearman_corr_w_target_nomi_20_reversals                                   0.000066
# spearman_corr_w_target_nomi_20_autocorr                                   -0.002773
#
#                                           feature_divulsive_explanatory_ideologue  \
# legacy_uniqueness                                                             NaN
# spearman_corr_w_target_nomi_20_mean                                     -0.001380
# spearman_corr_w_target_nomi_20_sharpe                                   -0.151656
# spearman_corr_w_target_nomi_20_reversals                                 0.000057
# spearman_corr_w_target_nomi_20_autocorr                                  0.024705
#
#                                           feature_ichthyotic_roofed_yeshiva  \
# legacy_uniqueness                                                       NaN
# spearman_corr_w_target_nomi_20_mean                               -0.000402
# spearman_corr_w_target_nomi_20_sharpe                             -0.055725
# spearman_corr_w_target_nomi_20_reversals                           0.000047
# spearman_corr_w_target_nomi_20_autocorr                           -0.002768
#
#                                           feature_waggly_outlandish_carbonisation  \
# legacy_uniqueness                                                             NaN
# spearman_corr_w_target_nomi_20_mean                                     -0.003208
# spearman_corr_w_target_nomi_20_sharpe                                   -0.321278
# spearman_corr_w_target_nomi_20_reversals                                 0.000072
# spearman_corr_w_target_nomi_20_autocorr                                  0.085657
#
#                                           feature_floriated_amish_sprite  \
# legacy_uniqueness                                                    NaN
# spearman_corr_w_target_nomi_20_mean                            -0.000495
# spearman_corr_w_target_nomi_20_sharpe                          -0.044572
# spearman_corr_w_target_nomi_20_reversals                        0.000097
# spearman_corr_w_target_nomi_20_autocorr                        -0.026051
#
#                                           feature_iconoclastic_parietal_agonist  \
# legacy_uniqueness                                                           NaN
# spearman_corr_w_target_nomi_20_mean                                   -0.001224
# spearman_corr_w_target_nomi_20_sharpe                                 -0.110762
# spearman_corr_w_target_nomi_20_reversals                               0.000083
# spearman_corr_w_target_nomi_20_autocorr                               -0.065386
#
#                                           ...  \
# legacy_uniqueness                         ...
# spearman_corr_w_target_nomi_20_mean       ...
# spearman_corr_w_target_nomi_20_sharpe     ...
# spearman_corr_w_target_nomi_20_reversals  ...
# spearman_corr_w_target_nomi_20_autocorr   ...
#
#                                           feature_aged_phylacterical_pusey  \
# legacy_uniqueness                                                      NaN
# spearman_corr_w_target_nomi_20_mean                              -0.004458
# spearman_corr_w_target_nomi_20_sharpe                            -0.227790
# spearman_corr_w_target_nomi_20_reversals                          0.000253
# spearman_corr_w_target_nomi_20_autocorr                           0.027398
#
#                                           feature_revisional_ablutionary_depression  \
# legacy_uniqueness                                                               NaN
# spearman_corr_w_target_nomi_20_mean                                       -0.004019
# spearman_corr_w_target_nomi_20_sharpe                                     -0.232866
# spearman_corr_w_target_nomi_20_reversals                                   0.000198
# spearman_corr_w_target_nomi_20_autocorr                                    0.067114
#
#                                           feature_yokelish_metapsychological_lunt  \
# legacy_uniqueness                                                             NaN
# spearman_corr_w_target_nomi_20_mean                                     -0.003716
# spearman_corr_w_target_nomi_20_sharpe                                   -0.222358
# spearman_corr_w_target_nomi_20_reversals                                 0.000194
# spearman_corr_w_target_nomi_20_autocorr                                  0.079840
#
#                                           feature_circumlunar_chaliced_seam  \
# legacy_uniqueness                                                       NaN
# spearman_corr_w_target_nomi_20_mean                               -0.004937
# spearman_corr_w_target_nomi_20_sharpe                             -0.243305
# spearman_corr_w_target_nomi_20_reversals                           0.000284
# spearman_corr_w_target_nomi_20_autocorr                            0.014948
#
#                                           feature_squallier_prototypal_dammar  \
# legacy_uniqueness                                                         NaN
# spearman_corr_w_target_nomi_20_mean                                 -0.004065
# spearman_corr_w_target_nomi_20_sharpe                               -0.220292
# spearman_corr_w_target_nomi_20_reversals                             0.000229
# spearman_corr_w_target_nomi_20_autocorr                              0.026475
#
#                                           feature_cognate_elating_ravine  \
# legacy_uniqueness                                                    NaN
# spearman_corr_w_target_nomi_20_mean                            -0.001634
# spearman_corr_w_target_nomi_20_sharpe                          -0.073468
# spearman_corr_w_target_nomi_20_reversals                        0.000290
# spearman_corr_w_target_nomi_20_autocorr                         0.013104
#
#                                           feature_ethiopian_carminative_retentivity  \
# legacy_uniqueness                                                               NaN
# spearman_corr_w_target_nomi_20_mean                                       -0.001637
# spearman_corr_w_target_nomi_20_sharpe                                     -0.080811
# spearman_corr_w_target_nomi_20_reversals                                   0.000237
# spearman_corr_w_target_nomi_20_autocorr                                   -0.034855
#
#                                           feature_alabamian_outlying_monitoring  \
# legacy_uniqueness                                                           NaN
# spearman_corr_w_target_nomi_20_mean                                   -0.001181
# spearman_corr_w_target_nomi_20_sharpe                                 -0.061743
# spearman_corr_w_target_nomi_20_reversals                               0.000217
# spearman_corr_w_target_nomi_20_autocorr                               -0.030465
#
#                                           feature_byzantine_festinate_mannose  \
# legacy_uniqueness                                                         NaN
# spearman_corr_w_target_nomi_20_mean                                 -0.001756
# spearman_corr_w_target_nomi_20_sharpe                               -0.080699
# spearman_corr_w_target_nomi_20_reversals                             0.000291
# spearman_corr_w_target_nomi_20_autocorr                              0.014946
#
#                                           feature_sleetier_sea_potamogeton
# legacy_uniqueness                                                      NaN
# spearman_corr_w_target_nomi_20_mean                              -0.001971
# spearman_corr_w_target_nomi_20_sharpe                            -0.091598
# spearman_corr_w_target_nomi_20_reversals                          0.000265
# spearman_corr_w_target_nomi_20_autocorr                          -0.000975
#
# [5 rows x 1586 columns]
